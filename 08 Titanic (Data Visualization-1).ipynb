# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset = sns.load_dataset('titanic')
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dataset.shape
# Out:
# (891, 15)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.jointplot(x='age', y='fare', data=dataset)

# %%
sns.boxplot(x='age', data=dataset, hue="survived")
# Out:
# <Axes: xlabel='age'>

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.jointplot(x='age', y='fare', data=dataset, kind='hex')

# %%
sns.histplot(data=dataset,x="fare",y="age")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
x=dataset["fare"]
x
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
sns.barplot(data=dataset,x="fare",y="age")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.pairplot(dataset)

# %%
sns.histplot(data=dataset,x="fare",binwidth=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df_cleaned=dataset.drop(['pclass','embarked','deck','embark_town'],axis=1)
sns.histplot(data=df_cleaned,x="fare",binwidth=30)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.barplot(data=df_cleaned,x="fare",y="age")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
df_cleaned.corr(method='pearson', numeric_only=True)
# Out:
#             survived       age     sibsp     parch      fare  adult_male  \
# survived    1.000000 -0.077221 -0.035322  0.081629  0.257307   -0.557080
# age        -0.077221  1.000000 -0.308247 -0.189119  0.096067    0.280328
# sibsp      -0.035322 -0.308247  1.000000  0.414838  0.159651   -0.253586
# parch       0.081629 -0.189119  0.414838  1.000000  0.216225   -0.349943
# fare        0.257307  0.096067  0.159651  0.216225  1.000000   -0.182024
# adult_male -0.557080  0.280328 -0.253586 -0.349943 -0.182024    1.000000
# alone      -0.203367  0.198270 -0.584471 -0.583398 -0.271832    0.404744
#
#                alone
# survived   -0.203367
# age         0.198270
# sibsp      -0.584471
# parch      -0.583398
# fare       -0.271832
# adult_male  0.404744
# alone       1.000000

# %%
df_cleaned.loc[:,["survived","alive"]]
# Out:
#      survived alive
# 0           0    no
# 1           1   yes
# 2           1   yes
# 3           1   yes
# 4           0    no
# ..        ...   ...
# 886         0    no
# 887         1   yes
# 888         0    no
# 889         1   yes
# 890         0    no
#
# [891 rows x 2 columns]

# %%
df_cleaned=dataset.drop(['pclass','embarked','deck','embark_town'],axis=1)
sns.boxplot(data=df_cleaned,x="sex",y="age", color="Purple")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=df_cleaned,x="sex",y="age",hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>
